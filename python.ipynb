# %%
phrase="Giraffe Academy"
print(phrase.index("A"))  # Output: 8
# Out:
# 8

# %%
phrase="Giraffe Academy"
print(phrase.index("a"))
# Out:
# 3

# %%
name=input("Name:")
age=input("Age:")
print("Hello " + name + "! You are " + age + " years old.")
# Out:
# Hello Ryan! You are 24 years old.

# %%
class Node:
    """ArithmeticError: Raised when an error occurs in numeric calculations."""

    data=None
    next=None

    def __init__(setf, data):
        self.data=data

    def __repr__(self):
        return "<Node data: %s>" % self.data
